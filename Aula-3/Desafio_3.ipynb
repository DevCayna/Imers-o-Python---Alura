# %% [markdown]
# <a href="https://colab.research.google.com/github/DevCayna/Imersao_Python_Alura/blob/main/Desafio_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importando Database

# %%
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-fb377116-238e-403f-b4e0-58eb022ece81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb377116-238e-403f-b4e0-58eb022ece81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Importando Bibliotecas

# %%
import pandas as pd

import plotly.express as px

# %% [markdown]
# #Criação de data

# %%
df_principal = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx",sheet_name="Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1  CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2  PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3  SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4  CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5  PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6  PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7  VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8  MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9  ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação %  \
# ...

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final','Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
# ...

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtd_teorica'})
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
# ...

# %%
df_principal = df_principal.rename(columns={'Variação (R$)':'Variacao_rs'}).copy()

# %%
df_total_acoes = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx",sheet_name="Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx",sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx",sheet_name="Chat Gpt")
df_chatgpt
# Out:
#      Nome da empresa           Segmento  Idade (anos)
# 0           Usiminas         Siderurgia            60
# 1      CSN Mineração          Mineração             8
# 2          Petrobras           Petróleo            69
# 3             Suzano   Papel e Celulose            94
# 4       CPFL Energia            Energia           109
# ..               ...                ...           ...
# 76  Carrefour Brasil             Varejo            37
# 77       Casas Bahia             Varejo            95
# 78          Localiza  Aluguel de Carros            49
# 79               CVC            Turismo            50
# 80               GOL            Aviação            20
#
# [81 rows x 3 columns]

# %%
df_principal_subiu = df_principal [df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# 5   PRIO3 2024-01-26        45.69         1.98           2.42         -0.78
# 6   PETR4 2024-01-26        39.96         1.73           6.47          7.30
# 7   VALE3 2024-01-26        69.50         1.66           2.06         -9.97
# 8   MULT3 2024-01-26        28.19         1.58           2.03         -0.81
# 9   ITUB4 2024-01-26        32.81         1.48          -0.39         -3.36
# 10  RDOR3 2024-01-26        27.56         1.43           3.41         -4.17
# ...

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#               Segmento   Variacao_rs
# 0            Alimentos  4.078337e+08
# 1              Aviação  6.545221e+07
# 2                Banco  3.740512e+09
# 3           Construção  3.752587e+07
# 4             Educação  7.229584e+07
# 5              Energia  1.209822e+09
# 6              Holding  4.160922e+08
# 7          Imobiliário  1.806845e+07
# 8            Logística  2.339027e+08
# 9   Meios de Pagamento  4.365768e+07
# 10           Mineração  4.940443e+09
# 11                Moda  4.102179e+07
# 12    Papel e Celulose  7.229463e+08
# 13            Petróleo  6.093289e+09
# 14             Química  6.905432e+07
# 15               Saúde  4.539179e+08
# 16    Shopping Centers  1.177327e+08
# 17          Siderurgia  4.899359e+08
# 18          Tecnologia  1.559889e+07
# 19    Telecomunicações  2.929381e+08
# 20              Varejo  2.371870e+08

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado   Variacao_rs
# 0    Desceu -6.338820e+09
# 1   Estável  0.000000e+00
# 2     Subiu  1.971923e+10

# %%
df_analise_cat_idade = df_principal.groupby('Categoria de idade')['Variacao_rs'].sum().reset_index()
df_analise_cat_idade
# Out:
#   Categoria de idade   Variacao_rs
# 0     Entre 50 e 100  1.120368e+10
# 1        Mais de 100 -2.024083e+08
# 2        Menos de 50  2.379139e+09

# %% [markdown]
# #Unindo planilhas

# %%
df_principal = df_principal.merge(df_total_acoes, left_on ='Ativo', right_on='Código', how='left' )
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
# ...

# %%
df_principal = df_principal.drop(columns={'Código'})
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
# ...

# %% [markdown]
# #Cálculos

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] / 100
df_principal['Valor_inicial'] = df_principal['valor_final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
# ...

# %%
# Calculando o maior valor
maior = df_principal['Variacao_rs'].max()

# Calculando o menor valor
menor = df_principal['Variacao_rs'].min()

# Calculando a média
media = df_principal['Variacao_rs'].mean()

# Calculando a média de quem subiu
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()

# Calculando a média de quem desceu
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

# Imprimindo os resultados
print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Média\tR$ {media:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 4,762,926,995.00
# Menor	R$ -1,807,432,634.00
# Média	R$ 165,190,210.49
# Média de quem subiu	R$ 448,164,250.23
# Média de quem desceu	R$ -181,109,141.73

# %% [markdown]
# #Alterando formatação de números (Int e float)

# %%
pd.options.display.float_format = '{:.2f}'.format
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
# ...

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtd_teorica'})
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
# ...

# %%
df_principal['Qtd_teorica'] = df_principal['Qtd_teorica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
# ...

# %% [markdown]
# #Gráficos

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y= 'Variacao_rs', text= 'Variacao_rs', title= 'Variação reais por resultado')
fig.update_traces(texttemplate='R$ %{text:,.2f}', textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df_analise_segmento, values='Variacao_rs', names='Segmento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df_analise_cat_idade, x='Categoria de idade', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Categoria de Idade')
fig.update_traces(texttemplate='R$ %{text:,.2f}', textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
